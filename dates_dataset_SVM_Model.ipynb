# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel(r"C:\Users\Admin\OneDrive\Desktop\dates_dataset.xlsx")

# %%
data.shape
# Out:
# (898, 35)

# %%
data.head()
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0  422163   2378.908    837.8484    645.6693        0.6373  733.1539
# 1  338136   2085.144    723.8198    595.2073        0.5690  656.1464
# 2  526843   2647.394    940.7379    715.3638        0.6494  819.0222
# 3  416063   2351.210    827.9804    645.2988        0.6266  727.8378
# 4  347562   2160.354    763.9877    582.8359        0.6465  665.2291
#
#    SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0    0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1    0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2    0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3    0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4    0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
#
#    KurtosisRB    EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  ALLdaub4RG  \
# ...

# %%
data.isnull().any()
# Out:
# AREA             False
# PERIMETER        False
# MAJOR_AXIS       False
# MINOR_AXIS       False
# ECCENTRICITY     False
# EQDIASQ          False
# SOLIDITY         False
# CONVEX_AREA      False
# EXTENT           False
# ASPECT_RATIO     False
# ROUNDNESS        False
# COMPACTNESS      False
# SHAPEFACTOR_1    False
# SHAPEFACTOR_2    False
# SHAPEFACTOR_3    False
# SHAPEFACTOR_4    False
# MeanRR           False
# MeanRG           False
# MeanRB           False
# StdDevRR         False
# StdDevRG         False
# StdDevRB         False
# SkewRR           False
# SkewRG           False
# SkewRB           False
# KurtosisRR       False
# KurtosisRG       False
# KurtosisRB       False
# EntropyRR        False
# EntropyRG        False
# EntropyRB        False
# ALLdaub4RR       False
# ALLdaub4RG       False
# ALLdaub4RB       False
# Class            False
# dtype: bool

# %%
data['Class'].unique()
# Out:
# array(['BERHI', 'DEGLET', 'DOKOL', 'IRAQI', 'ROTANA', 'SAFAVI', 'SOGAY'],
#       dtype=object)

# %%
data.describe().transpose()
# Out:
#                count          mean           std           min           25%  \
# AREA           898.0  2.982952e+05  1.072452e+05  1.987000e+03  2.069480e+05
# PERIMETER      898.0  2.057661e+03  4.100125e+02  9.118280e+02  1.726091e+03
# MAJOR_AXIS     898.0  7.508120e+02  1.440593e+02  3.367227e+02  6.410686e+02
# MINOR_AXIS     898.0  4.958728e+02  1.142689e+02  2.283200e+00  4.046844e+02
# ECCENTRICITY   898.0  7.374678e-01  8.872739e-02  3.448000e-01  6.856250e-01
# EQDIASQ        898.0  6.045779e+02  1.195939e+02  5.029840e+01  5.133171e+02
# SOLIDITY       898.0  9.818403e-01  1.815742e-02  8.366000e-01  9.788250e-01
# CONVEX_AREA    898.0  3.038456e+05  1.088157e+05  2.257000e+03  2.100228e+05
# EXTENT         898.0  7.362671e-01  5.374518e-02  5.123000e-01  7.058750e-01
# ASPECT_RATIO   898.0  2.131102e+00  1.782078e+01  1.065300e+00  1.373725e+00
# ROUNDNESS      898.0  8.577200e-01  7.083882e-02  4.800000e-03  8.277500e-01
# ...

# %%
data_corr = data.corr()

# %%
data_corr
# Out:
#                    AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# AREA           1.000000   0.956494    0.878893    0.954899     -0.370303
# PERIMETER      0.956494   1.000000    0.960734    0.859990     -0.166816
# MAJOR_AXIS     0.878893   0.960734    1.000000    0.721133      0.063090
# MINOR_AXIS     0.954899   0.859990    0.721133    1.000000     -0.607120
# ECCENTRICITY  -0.370303  -0.166816    0.063090   -0.607120      1.000000
# EQDIASQ        0.993243   0.959938    0.886277    0.948006     -0.335085
# SOLIDITY       0.027371  -0.133857   -0.166982    0.059613     -0.220434
# CONVEX_AREA    0.998886   0.963489    0.886948    0.951470     -0.356565
# EXTENT        -0.086286  -0.214632   -0.279951    0.028003     -0.342775
# ASPECT_RATIO  -0.095342   0.018308    0.111631   -0.150407      0.110238
# ROUNDNESS      0.044346  -0.235744   -0.355258    0.243655     -0.659626
# COMPACTNESS    0.315197   0.078554   -0.164403    0.551966     -0.917470
# ...

# %%
fig = plt.figure(figsize=(15,12))
r = sns.heatmap(data_corr,cmap = 'Purples')
r.set_title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
sns.countplot(data['Class'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
x = data.drop('Class', axis = 1)
y = data['Class']   #0, 1, 2, 3 classification clusters

scaler.fit(x)
x_transformed = scaler.transform(x)
# transforming data into a standard scale 0-1

x_train, x_test, y_train, y_test = train_test_split(x_transformed, y, test_size = 0.20)

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix

# %%
print("Train set Accuracy: ",accuracy_score(y_train_pred, y_train)*100)
print("Test set Accuracy: ", accuracy_score(y_test_pred, y_test)*100)
print("\nConfusion Matric: \n",confusion_matrix(y_test_pred, y_test))
print("\nClassification Report: \n",classification_report(y_test_pred, y_test))
# Out:
# Train set Accuracy:  92.61838440111421
# Test set Accuracy:  92.77777777777779
#
# Confusion Matric:
#  [[ 6  0  0  0  0  0  0]
#  [ 0 13  1  0  1  0  3]
#  [ 0  4 46  0  0  0  0]
#  [ 1  0  0 10  0  0  0]
#  [ 0  0  0  0 33  0  0]
#  [ 0  0  0  0  0 45  0]
#  [ 1  0  0  0  2  0 14]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        BERHI       0.75      1.00      0.86         6
#       DEGLET       0.76      0.72      0.74        18
#        DOKOL       0.98      0.92      0.95        50
#        IRAQI       1.00      0.91      0.95        11
#       ROTANA       0.92      1.00      0.96        33
#       SAFAVI       1.00      1.00      1.00        45
#        SOGAY       0.82      0.82      0.82        17
#
#     accuracy                           0.93       180
#    macro avg       0.89      0.91      0.90       180
# weighted avg       0.93      0.93      0.93       180
